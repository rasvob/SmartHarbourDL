# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %% [markdown]
# Lets parse annotations from XML file, use all attributes saved by CVAT annotation tool and check which attributes can be ommited.

# %%
def parse_annotations_tracks(soup: object):
    frame_annotation_data = list()
    tasks_data = list()
    for task in soup.find_all('task'):
        tasks_data.append({
            'task_id': task.find('id').text,
            'name': task.find('name').text,
        })
    tasks_df = pd.DataFrame(tasks_data)
    tasks_df['camera_id'] = tasks_df['name'].apply(lambda x: x.split('_')[3])
    tasks_df['datetime'] = tasks_df['name'].apply(lambda x: x.split('_')[6].replace('.mkv', ''))
    tasks_df['datetime'] = pd.to_datetime(tasks_df['datetime'], format='%Y%m%dT%H%M%S')
    tasks_df.set_index('task_id', inplace=True)
    for track in soup.findAll('track'):
        track_annotation_dict = {}
        for attribute_name in ['id', 'label', 'source', 'task_id', 'subset']:
            track_annotation_dict[attribute_name] = track[attribute_name]
        label = track['label']
        for box in track.findAll('box'):
            frame_annotation_dict = track_annotation_dict.copy()
            for attribute_name in ['frame', 'keyframe', 'outside', 'occluded', 'xtl', 'ytl', 'xbr', 'ybr', 'z_order']:
                frame_annotation_dict[attribute_name] = box[attribute_name]

            if label == 'spz':
                frame_annotation_dict['text_spz'] = box.find('attribute', {'name': 'text_spz'}).text
            if label == 'spz_alt':
                frame_annotation_dict['text_spz'] = box.find('attribute', {'name': 'spz_alt_text'}).text
            elif label == 'text':
                frame_annotation_dict['unspecified_text'] = box.find('attribute', {'name': 'unspecified_text'}).text

            frame_annotation_dict['name'] = tasks_df.loc[frame_annotation_dict['task_id'], 'name']
            frame_annotation_dict['camera_id'] = tasks_df.loc[frame_annotation_dict['task_id'],'camera_id']
            frame_annotation_dict['datetime'] = tasks_df.loc[frame_annotation_dict['task_id'],'datetime']
            frame_annotation_data.append(frame_annotation_dict)

    frame_annotation_df = pd.DataFrame(frame_annotation_data)
    return frame_annotation_df


with open('project_camera_01_09_to_11_06_23-2023_07_20_12_42_13-cvat for video 1.1.xml', 'r', encoding='utf-8') as f:
	xml_annotations = f.read() 
soup = BeautifulSoup(xml_annotations, 'xml')
frame_annotation_df_1 = parse_annotations_tracks(soup)

with open('project_camera_02_09_to_11_06_23-2023_07_17_13_14_54-cvat for video 1.1.xml', 'r', encoding='utf-8') as f:
    xml_annotations = f.read() 
soup = BeautifulSoup(xml_annotations, 'xml')
frame_annotation_df_2 = parse_annotations_tracks(soup)

frame_annotation_df = pd.concat([frame_annotation_df_1, frame_annotation_df_2])
frame_annotation_df.rename({'id': 'track_id'}, axis=1, inplace=True)
frame_annotation_df.reset_index(drop=True, inplace=True)
frame_annotation_df.shape
# Out:
# (43437, 19)

# %%
frame_annotation_df
# Out:
#       track_id    label     source task_id   subset   frame keyframe outside  \
# 0            0     boat  semi-auto       1  default    1087        1       0
# 1            0     boat  semi-auto       1  default    1088        1       0
# 2            0     boat  semi-auto       1  default    1089        1       0
# 3            0     boat  semi-auto       1  default    1090        1       0
# 4            0     boat  semi-auto       1  default    1091        1       0
# ...        ...      ...        ...     ...      ...     ...      ...     ...
# 43432      627  spz_alt  semi-auto     699  default  933691        1       0
# 43433      627  spz_alt  semi-auto     699  default  933692        1       0
# 43434      627  spz_alt  semi-auto     699  default  933693        1       0
# 43435      627  spz_alt  semi-auto     699  default  933694        1       1
# 43436      628  anomaly     manual     668  default  861006        1       0
#
#       occluded      xtl     ytl      xbr      ybr z_order  \
# 0            0  1238.46  503.65  1425.55   585.23       0
# 1            0  1238.00  502.00  1425.00   583.00       0
# 2            0  1239.00  503.00  1426.00   584.00       0
# 3            0  1239.00  503.00  1426.00   584.00       0
# 4            0  1239.00  503.00  1426.00   584.00       0
# ...        ...      ...     ...      ...      ...     ...
# 43432        0   115.36  527.69   226.60   579.69       0
# 43433        0    60.00  530.67   171.00   582.67       0
# 43434        0    11.33  542.00   122.33   594.00       0
# 43435        0     0.00  543.00    72.33   595.00       0
# 43436        0   830.80    0.00  1913.27  1076.89       0
#
#                                               name camera_id  \
# 0      cfg_raw_cam_01_fhd_h265_20230609T050002.mkv        01
# 1      cfg_raw_cam_01_fhd_h265_20230609T050002.mkv        01
# 2      cfg_raw_cam_01_fhd_h265_20230609T050002.mkv        01
# 3      cfg_raw_cam_01_fhd_h265_20230609T050002.mkv        01
# 4      cfg_raw_cam_01_fhd_h265_20230609T050002.mkv        01
# ...                                            ...       ...
# 43432  cfg_raw_cam_02_fhd_h265_20230707T190001.mkv        02
# 43433  cfg_raw_cam_02_fhd_h265_20230707T190001.mkv        02
# 43434  cfg_raw_cam_02_fhd_h265_20230707T190001.mkv        02
# 43435  cfg_raw_cam_02_fhd_h265_20230707T190001.mkv        02
# 43436  cfg_raw_cam_02_fhd_h265_20230707T135003.mkv        02
#
#                  datetime text_spz unspecified_text
# 0     2023-06-09 05:00:02      NaN              NaN
# 1     2023-06-09 05:00:02      NaN              NaN
# 2     2023-06-09 05:00:02      NaN              NaN
# 3     2023-06-09 05:00:02      NaN              NaN
# 4     2023-06-09 05:00:02      NaN              NaN
# ...                   ...      ...              ...
# 43432 2023-07-07 19:00:01  Martina              NaN
# 43433 2023-07-07 19:00:01  Martina              NaN
# 43434 2023-07-07 19:00:01  Martina              NaN
# 43435 2023-07-07 19:00:01  Martina              NaN
# 43436 2023-07-07 13:50:03      NaN              NaN
#
# [43437 rows x 19 columns]

# %%
frame_annotation_df.describe()
# Out:
#                             datetime
# count                          43437
# mean   2023-06-21 15:13:26.134263552
# min              2023-06-09 05:00:02
# 25%              2023-06-09 14:10:03
# 50%              2023-06-10 13:00:00
# 75%              2023-07-07 15:10:01
# max              2023-07-08 20:00:03

# %%
for attribute_name in ['track_id', 'frame']:
    frame_annotation_df[attribute_name] = frame_annotation_df[attribute_name].astype(int)
for attribute_name in ['xtl', 'ytl', 'xbr', 'ybr']:
    frame_annotation_df[attribute_name] = frame_annotation_df[attribute_name].astype(float)

# %% [markdown]
# # Boat transit aggregation with boat identification
#
# - Form a boat area transit dataframe with aggregation of boat passing in camera view and boat identification values.
# - Fill missing annotation data

# %%
def decode_usable_spz(row:pd.Series):
    text_spz = row['text_spz']
    if pd.isna(text_spz):
        return '', 0
    text_spz = text_spz.replace('!', '').replace('#', '')    
    text_spz = text_spz.replace(' ', '')
    if text_spz == '???':
        return '', 0
    
    text_spz_known = text_spz.replace('?', '')
    return text_spz, len(text_spz_known)

frame_annotation_df['decoded_spz'], frame_annotation_df['usable_spz_len'] = zip(*frame_annotation_df.apply(decode_usable_spz, axis=1))

# %%
frame_annotation_df
# Out:
#        track_id    label     source task_id   subset   frame keyframe outside  \
# 0             0     boat  semi-auto       1  default    1087        1       0
# 1             0     boat  semi-auto       1  default    1088        1       0
# 2             0     boat  semi-auto       1  default    1089        1       0
# 3             0     boat  semi-auto       1  default    1090        1       0
# 4             0     boat  semi-auto       1  default    1091        1       0
# ...         ...      ...        ...     ...      ...     ...      ...     ...
# 43432       627  spz_alt  semi-auto     699  default  933691        1       0
# 43433       627  spz_alt  semi-auto     699  default  933692        1       0
# 43434       627  spz_alt  semi-auto     699  default  933693        1       0
# 43435       627  spz_alt  semi-auto     699  default  933694        1       1
# 43436       628  anomaly     manual     668  default  861006        1       0
#
#       occluded      xtl  ...      xbr      ybr  z_order  \
# 0            0  1238.46  ...  1425.55   585.23        0
# 1            0  1238.00  ...  1425.00   583.00        0
# 2            0  1239.00  ...  1426.00   584.00        0
# 3            0  1239.00  ...  1426.00   584.00        0
# 4            0  1239.00  ...  1426.00   584.00        0
# ...        ...      ...  ...      ...      ...      ...
# 43432        0   115.36  ...   226.60   579.69        0
# 43433        0    60.00  ...   171.00   582.67        0
# 43434        0    11.33  ...   122.33   594.00        0
# 43435        0     0.00  ...    72.33   595.00        0
# 43436        0   830.80  ...  1913.27  1076.89        0
#
#                                               name camera_id  \
# 0      cfg_raw_cam_01_fhd_h265_20230609T050002.mkv        01
# 1      cfg_raw_cam_01_fhd_h265_20230609T050002.mkv        01
# 2      cfg_raw_cam_01_fhd_h265_20230609T050002.mkv        01
# 3      cfg_raw_cam_01_fhd_h265_20230609T050002.mkv        01
# 4      cfg_raw_cam_01_fhd_h265_20230609T050002.mkv        01
# ...                                            ...       ...
# 43432  cfg_raw_cam_02_fhd_h265_20230707T190001.mkv        02
# 43433  cfg_raw_cam_02_fhd_h265_20230707T190001.mkv        02
# 43434  cfg_raw_cam_02_fhd_h265_20230707T190001.mkv        02
# 43435  cfg_raw_cam_02_fhd_h265_20230707T190001.mkv        02
# 43436  cfg_raw_cam_02_fhd_h265_20230707T135003.mkv        02
#
#                  datetime text_spz unspecified_text decoded_spz usable_spz_len
# 0     2023-06-09 05:00:02      NaN              NaN                          0
# 1     2023-06-09 05:00:02      NaN              NaN                          0
# 2     2023-06-09 05:00:02      NaN              NaN                          0
# 3     2023-06-09 05:00:02      NaN              NaN                          0
# 4     2023-06-09 05:00:02      NaN              NaN                          0
# ...                   ...      ...              ...         ...            ...
# 43432 2023-07-07 19:00:01  Martina              NaN     Martina              7
# 43433 2023-07-07 19:00:01  Martina              NaN     Martina              7
# 43434 2023-07-07 19:00:01  Martina              NaN     Martina              7
# 43435 2023-07-07 19:00:01  Martina              NaN     Martina              7
# 43436 2023-07-07 13:50:03      NaN              NaN                          0
#
# [43437 rows x 21 columns]

# %% [markdown]
# Attributes with unique value count equal 1 can be droped from dataframe.

# %%
frame_annotation_df.label.value_counts()
# Out:
# label
# boat        24769
# spz          7895
# spz_alt      3415
# anomaly      3384
# text         3300
# boat_alt      674
# Name: count, dtype: int64

# %%
frame_annotation_df.groupby(['camera_id','label']).track_id.unique()
# Out:
# camera_id  label
# 01         anomaly                     [3, 101, 108, 113, 118, 123, 182]
#            boat        [0, 1, 4, 8, 13, 15, 19, 24, 27, 30, 35, 39, 4...
#            boat_alt                                      [184, 202, 231]
#            spz         [2, 5, 11, 16, 20, 25, 28, 31, 36, 40, 47, 52,...
#            spz_alt                                  [187, 232, 310, 349]
#            text        [6, 7, 9, 10, 12, 14, 17, 18, 21, 22, 23, 26, ...
# 02         anomaly                [54, 55, 126, 423, 437, 494, 585, 628]
#            boat        [0, 3, 6, 8, 10, 13, 16, 19, 21, 24, 27, 30, 3...
#            boat_alt         [53, 183, 187, 194, 199, 278, 317, 478, 571]
#            spz         [1, 4, 7, 11, 14, 17, 20, 22, 25, 28, 32, 34, ...
#            spz_alt     [2, 5, 9, 12, 15, 18, 23, 26, 29, 31, 41, 43, ...
# Name: track_id, dtype: object

# %%
frame_annotation_df.groupby(['camera_id','label']).track_id.unique().apply(len)
# Out:
# camera_id  label
# 01         anomaly       7
#            boat        126
#            boat_alt      3
#            spz          93
#            spz_alt       4
#            text        119
# 02         anomaly       8
#            boat        275
#            boat_alt      9
#            spz         210
#            spz_alt     127
# Name: track_id, dtype: int64

# %% [markdown]
# Parse table of boat traversals. Find a tracks connected to each other. The ones that are relevant for boat traversal record.

# %%
tracks_frame_range_df = frame_annotation_df.groupby(['camera_id', 'track_id']).frame.agg(['min', 'max']).sort_index().join(frame_annotation_df.groupby('track_id').label.first())
tracks_frame_range_df
# Out:
#                        min     max    label
# camera_id track_id
# 01        0           1087    1108     boat
#           1          25048   25143     boat
#           2          25090   25129      spz
#           3          37492   37530  anomaly
#           4          58362   58428     boat
# ...                    ...     ...      ...
# 02        624       935635  935663      spz
#           625       933659  933704     boat
#           626       933659  933695      spz
#           627       933659  933694  spz_alt
#           628       861006  861006  anomaly
#
# [981 rows x 3 columns]

# %%
def select_representative_text_from_frames_series(text_series: pd.Series):
    text_series = text_series.dropna()
    if text_series.empty:
        return np.nan
    text_series = text_series.str.replace('#', '').replace('!', '')

    text_df = text_series.reset_index()
    text_df.columns = ['frame', 'text']
    text_df['len'] = text_df.text.str.len()
    return text_df.sort_values('len', ascending=False).iloc[0]['text']

# %%
boats_traversal_df = tracks_frame_range_df[tracks_frame_range_df.label.isin(['boat', 'boat_alt'])].copy().reset_index()
boats_traversal_df.columns = ['camera_id', 'boat_track_id', 'frame_id_min', 'frame_id_max', 'label']
boats_traversal_df['decoded_spz'] = np.nan
boats_traversal_df['decoded_text'] = np.nan

for id, row in list(boats_traversal_df.iterrows()):
    camera_tracks_frame_range_df = tracks_frame_range_df.loc[row.camera_id]
    additional_boat_info_df = camera_tracks_frame_range_df[(camera_tracks_frame_range_df['min'] >= row.frame_id_min) & (camera_tracks_frame_range_df['max'] <= row.frame_id_max) & (camera_tracks_frame_range_df['label'] != 'boat')]
    # print(additional_boat_info_df)
    decoded_info_msg = f'For boat track_id={row.boat_track_id}:'
    if additional_boat_info_df.size > 0:
        spz_info = additional_boat_info_df[additional_boat_info_df.label == ('spz_alt' if row.label == 'boat_alt' else 'spz')] 
        # print(spz_info.iloc[0].name)
        if spz_info.size > 0:
            decoded_spz = frame_annotation_df[(frame_annotation_df.track_id == spz_info.iloc[0].name)][['text_spz', 'decoded_spz', 'usable_spz_len']].sort_values('usable_spz_len', ascending=False).iloc[0]['decoded_spz']
            boats_traversal_df.loc[id, 'decoded_spz'] = decoded_spz
            decoded_info_msg += f' decoded_spz={decoded_spz},'
        else:
            decoded_info_msg += f' no spz found,'

        text_info = additional_boat_info_df[additional_boat_info_df.label == 'text']
        if text_info.size > 0:    
            decoded_text = ';'.join([select_representative_text_from_frames_series(frame_annotation_df[(frame_annotation_df.track_id == text_track_id)]['unspecified_text']) for text_track_id in text_info.index])
            boats_traversal_df.loc[id, 'decoded_text'] = decoded_text
            decoded_info_msg += f' decoded_text={decoded_text},'
        else:
            decoded_info_msg += f' no text found,'

        other_info = additional_boat_info_df[~additional_boat_info_df.label.isin(['spz', 'text'])]
        if other_info.size > 0:
            decoded_info_msg += f' other_info={other_info.to_dict()},'
    else:
        decoded_info_msg += f' no additional info was found.'

    print(decoded_info_msg)
        
boats_traversal_df
# Out:
# For boat track_id=0: no additional info was found.
# For boat track_id=1: decoded_spz=www.hausbotvilma.cz, no text found,
# For boat track_id=4: decoded_spz=303451-P, decoded_text=www.housbotvilma.cz;Max. 10 Osob,
# For boat track_id=8: decoded_spz=303768-P, decoded_text=BLATOUCH;PŮJČOVNA-3;pronajemhousebotu.cz,
# For boat track_id=13: no spz found, decoded_text=LINKA STRÁŽNICE - PETROC A ZPĚT Tel.: 603 371 350,
# For boat track_id=15: decoded_spz=3043?4?, decoded_text=Amálka;???,
# For boat track_id=19: decoded_spz=600711-P, decoded_text=SASANKA;PŮJČOVNA-4;pronajemhousbotu.cz,
# For boat track_id=24: decoded_spz=600042-P, decoded_text=MAX. 8 osob,
# For boat track_id=27: decoded_spz=P-600752, decoded_text=???,
# For boat track_id=30: decoded_spz=BRITA, decoded_text=???;???;???,
# For boat track_id=35: decoded_spz=, decoded_text=???;???,
# For boat track_id=39: decoded_spz=600409, decoded_text=???;???;???,
# For boat track_id=44: no spz found, decoded_text=???,
# For boat track_id=46: decoded_spz=, decoded_text=???;???;???,
# For boat track_id=51: decoded_spz=600042-P, decoded_text=MAX. 8 osob,
# For boat track_id=54: decoded_spz=303451-P, decoded_text=www.housbotvilma.cz;Max. 10 Osob,
# For boat track_id=58: decoded_spz=fP-600792, decoded_text=MONTY,
# For boat track_id=61: decoded_spz=303756-P, decoded_text=Martina;!???,
# For boat track_id=65: decoded_spz=f304173-P, decoded_text=Martina;!???,
# For boat track_id=69: decoded_spz=303758-P, decoded_text=BLATOUCH;PŮJČOVNA-3;pronajemhousbotu.cz,
# For boat track_id=74: decoded_spz=304173-P, decoded_text=PŮJČOVNA LODÍ ?????,
# For boat track_id=77: decoded_spz=LINKASTRÁŽNICE-PETROVAZPĚTTel.:603371350, decoded_text=MAX. 8 osob,
# For boat track_id=80: decoded_spz=30308?-P, decoded_text=MAX. 8 osob,
# For boat track_id=83: decoded_spz=304173-P, decoded_text=BETY;PŮJČOVNA LODÍ ?????,
# For boat track_id=87: no spz found, decoded_text= LINKA STRÁŽNICE - PETROV A ZPĚT Tel.: 603 373 350,
# For boat track_id=89: no additional info was found.
# For boat track_id=90: decoded_spz=303890-P, decoded_text=PANAMA;PŮJČOVNA,
# For boat track_id=94: decoded_spz=Jeronimo, decoded_text=???,
# For boat track_id=97: decoded_spz=, decoded_text=???,
# For boat track_id=100: decoded_spz=600764-P, decoded_text=???;???;???;MAX. 10 OSOB, other_info={'min': {101: 136537}, 'max': {101: 136578}, 'label': {101: 'anomaly'}},
# For boat track_id=107: decoded_spz=P-600034, decoded_text=Půjčovna;???, other_info={'min': {108: 136734}, 'max': {108: 136772}, 'label': {108: 'anomaly'}},
# For boat track_id=112: decoded_spz=304173-P, decoded_text=???;???;???, other_info={'min': {113: 136834}, 'max': {113: 136890}, 'label': {113: 'anomaly'}},
# For boat track_id=119: decoded_spz=107302, decoded_text=???,
# For boat track_id=122: no spz found, decoded_text=LINKA STRÁŽNICE - PETROV A ZPĚT Tel.: 603 371 350, other_info={'min': {123: 146843}, 'max': {123: 146863}, 'label': {123: 'anomaly'}},
# For boat track_id=125: decoded_spz=, decoded_text=Jacht Morava;Anabela;tel.: 603 106 691,
# For boat track_id=130: decoded_spz=Martina, no text found,
# For boat track_id=132: decoded_spz=P-600752, decoded_text=MONTY,
# For boat track_id=135: decoded_spz=304173-P, decoded_text=PŮJČOVNA LODÍ ?????,
# For boat track_id=138: decoded_spz=600297, decoded_text=Jacht Morava;!Ale?andra;!tel.: 603 106 691,
# For boat track_id=143: decoded_spz=P-600395, decoded_text=AMBI,
# For boat track_id=146: no additional info was found.
# For boat track_id=147: decoded_spz=, no text found,
# For boat track_id=149: decoded_spz=, decoded_text=SÁRA;PŮJČOVNA,
# For boat track_id=153: decoded_spz=401990, decoded_text=SÁRA;PŮJČOVNA,
# For boat track_id=157: no additional info was found.
# For boat track_id=158: decoded_spz=60141?-P, decoded_text=???;???,
# For boat track_id=162: decoded_spz=600418, decoded_text=!Viktork?,
# For boat track_id=165: decoded_spz=600295, no text found,
# For boat track_id=167: decoded_spz=, decoded_text=???,
# For boat track_id=170: decoded_spz=, decoded_text=???,
# For boat track_id=173: decoded_spz=303084-P, decoded_text=MAX. 8 osob,
# For boat track_id=176: decoded_spz=303084-P, decoded_text=MAX. 8 osob,
# For boat track_id=179: decoded_spz=600293, decoded_text=???, other_info={'min': {182: 746724}, 'max': {182: 746758}, 'label': {182: 'anomaly'}},
# For boat track_id=183: decoded_spz=600293, decoded_text=???;Půjčovna, other_info={'min': {187: 747709}, 'max': {187: 747737}, 'label': {187: 'spz_alt'}},
# For boat track_id=184: decoded_spz=600494, decoded_text=???;Půjčovna, other_info={'min': {184: 747700, 187: 747709}, 'max': {184: 747771, 187: 747737}, 'label': {184: 'boat_alt', 187: 'spz_alt'}},
# For boat track_id=189: no additional info was found.
# For boat track_id=190: no spz found, decoded_text=???,
# For boat track_id=192: decoded_spz=???37?-P, no text found,
# For boat track_id=194: decoded_spz=600711-P, no text found,
# For boat track_id=196: decoded_spz=600042-P, decoded_text=MAX. 8 osob,
# For boat track_id=199: no spz found, decoded_text=???,
# For boat track_id=201: decoded_spz=, no text found,
# For boat track_id=202: no spz found, no text found, other_info={'min': {202: 758022}, 'max': {202: 758090}, 'label': {202: 'boat_alt'}},
# For boat track_id=204: decoded_spz=6005?7-P, decoded_text=???;???,
# For boat track_id=208: no spz found, decoded_text=???,
# For boat track_id=210: decoded_spz=50087?, decoded_text=LINKA STRÁŽNICE - PETROV A ZPĚT Tel.: 603 371 350,
# For boat track_id=213: decoded_spz=600293, decoded_text=???,
# For boat track_id=216: decoded_spz=304173-P, decoded_text=???,
# For boat track_id=219: decoded_spz=, no text found,
# For boat track_id=221: decoded_spz=, no text found,
# For boat track_id=223: decoded_spz=304???P, decoded_text=PŮJČOVNA,
# For boat track_id=226: decoded_spz=601095-P, no text found,
# For boat track_id=228: decoded_spz=601?55-P, no text found,
# For boat track_id=230: no spz found, no text found, other_info={'min': {232: 767159}, 'max': {232: 767168}, 'label': {232: 'spz_alt'}},
# For boat track_id=231: decoded_spz=, no text found, other_info={'min': {231: 767159, 232: 767159}, 'max': {231: 767203, 232: 767168}, 'label': {231: 'boat_alt', 232: 'spz_alt'}},
# For boat track_id=233: decoded_spz=BELINDA, decoded_text=???,
# For boat track_id=236: decoded_spz=600293, decoded_text=???,
# For boat track_id=239: decoded_spz=Boženka, decoded_text=???;???,
# For boat track_id=243: decoded_spz=303585-P, decoded_text=PANNONIA;PŮJČOVNA,
# For boat track_id=247: no spz found, decoded_text=???,
# For boat track_id=249: decoded_spz=600293, no text found,
# For boat track_id=251: no additional info was found.
# For boat track_id=252: decoded_spz=, no text found,
# For boat track_id=254: no spz found, decoded_text=JAGUAR;???,
# For boat track_id=257: decoded_spz=600293, decoded_text=???,
# For boat track_id=260: decoded_spz=Elektra, decoded_text=???,
# For boat track_id=263: decoded_spz=600042-P, decoded_text=MAX. 8 osob,
# For boat track_id=266: no spz found, decoded_text=!MAX. 8 osob,
# For boat track_id=268: decoded_spz=600?94, decoded_text=???;Půjčovna,
# For boat track_id=272: decoded_spz=, decoded_text=???,
# For boat track_id=275: decoded_spz=BIANCA, decoded_text=???,
# For boat track_id=278: no spz found, decoded_text=???;???,
# For boat track_id=281: no spz found, decoded_text=!MAX. 8 osob,
# For boat track_id=283: decoded_spz=KASANDRA, decoded_text=Jacht Morava;Alessia,
# For boat track_id=287: decoded_spz=???409-P, decoded_text=LINKA STRÁŽNICE - PETROV A ZPĚT Tel.: 603 371 350,
# For boat track_id=290: decoded_spz=30?084-P, decoded_text=MAX. 8 osob,
# For boat track_id=293: decoded_spz=, decoded_text=???,
# For boat track_id=296: decoded_spz=, decoded_text=JAGUAR;???,
# For boat track_id=300: no additional info was found.
# For boat track_id=301: decoded_spz=303955-P, decoded_text=???,
# For boat track_id=304: decoded_spz=601477-P, decoded_text=???,
# For boat track_id=307: no additional info was found.
# For boat track_id=308: decoded_spz=303585-P, no text found, other_info={'min': {310: 809049}, 'max': {310: 809063}, 'label': {310: 'spz_alt'}},
# For boat track_id=311: decoded_spz=334005-P, no text found,
# For boat track_id=313: decoded_spz=600657-P, no text found,
# For boat track_id=315: no additional info was found.
# For boat track_id=316: no additional info was found.
# For boat track_id=317: no additional info was found.
# For boat track_id=318: no additional info was found.
# For boat track_id=319: no additional info was found.
# For boat track_id=320: no additional info was found.
# For boat track_id=321: decoded_spz=60075?, no text found,
# For boat track_id=323: decoded_spz=601723-P, no text found,
# For boat track_id=325: decoded_spz=???084-P, no text found,
# For boat track_id=327: decoded_spz=, no text found,
# For boat track_id=329: decoded_spz=600293, no text found,
# For boat track_id=331: no additional info was found.
# For boat track_id=332: no additional info was found.
# For boat track_id=333: decoded_spz=60029?, no text found,
# For boat track_id=335: no additional info was found.
# For boat track_id=336: no additional info was found.
# For boat track_id=337: decoded_spz=, no text found,
# For boat track_id=339: decoded_spz=3030?4-P, no text found,
# For boat track_id=341: no additional info was found.
# For boat track_id=342: no additional info was found.
# For boat track_id=343: decoded_spz=600792, no text found,
# For boat track_id=345: decoded_spz=600296, no text found,
# For boat track_id=347: decoded_spz=304095-P, no text found, other_info={'min': {349: 877364}, 'max': {349: 877391}, 'label': {349: 'spz_alt'}},
# For boat track_id=350: decoded_spz=fg304095-P, no text found,
# For boat track_id=0: decoded_spz=www.hausbotvilma.cz, no text found,
# For boat track_id=1: no additional info was found.
# For boat track_id=4: decoded_spz=303451-P, no text found,
# For boat track_id=8: no spz found, decoded_text=BLATOUCH,
# For boat track_id=13: no spz found, decoded_text=LINKA STRÁŽNICE - PETROC A ZPĚT Tel.: 603 371 350,
# For boat track_id=15: no additional info was found.
# For boat track_id=19: decoded_spz=600711-P, no text found,
# For boat track_id=24: decoded_spz=600042-P, decoded_text=MAX. 8 osob,
# For boat track_id=27: decoded_spz=P-600752, decoded_text=???,
# For boat track_id=30: decoded_spz=BRITA, decoded_text=???,
# For boat track_id=35: decoded_spz=, no text found,
# For boat track_id=39: decoded_spz=600409, decoded_text=???,
# For boat track_id=44: no additional info was found.
# For boat track_id=46: no additional info was found.
# For boat track_id=51: decoded_spz=600042-P, no text found,
# For boat track_id=54: no additional info was found.
# For boat track_id=58: no additional info was found.
# For boat track_id=61: no additional info was found.
# For boat track_id=65: decoded_spz=f304173-P, decoded_text=Martina,
# For boat track_id=69: no additional info was found.
# For boat track_id=74: decoded_spz=304173-P, decoded_text=PŮJČOVNA LODÍ ?????,
# For boat track_id=77: decoded_spz=LINKASTRÁŽNICE-PETROVAZPĚTTel.:603371350, no text found,
# For boat track_id=80: no additional info was found.
# For boat track_id=83: no additional info was found.
# For boat track_id=87: no additional info was found.
# For boat track_id=89: no additional info was found.
# For boat track_id=90: no additional info was found.
# For boat track_id=94: decoded_spz=Jeronimo, no text found,
# For boat track_id=97: no additional info was found.
# For boat track_id=100: decoded_spz=600764-P, no text found, other_info={'min': {101: 144003}, 'max': {101: 144018}, 'label': {101: 'anomaly'}},
# For boat track_id=107: no additional info was found.
# For boat track_id=112: no additional info was found.
# For boat track_id=119: no additional info was found.
# For boat track_id=122: no additional info was found.
# For boat track_id=125: no additional info was found.
# For boat track_id=130: no additional info was found.
# For boat track_id=132: no additional info was found.
# For boat track_id=135: decoded_spz=304173-P, decoded_text=PŮJČOVNA LODÍ ?????,
# For boat track_id=138: decoded_spz=600297, no text found,
# For boat track_id=143: no additional info was found.
# For boat track_id=146: no additional info was found.
# For boat track_id=147: no additional info was found.
# For boat track_id=149: no additional info was found.
# For boat track_id=153: decoded_spz=401990, no text found,
# For boat track_id=157: no additional info was found.
# For boat track_id=158: no spz found, decoded_text=???,
# For boat track_id=162: no additional info was found.
# For boat track_id=165: decoded_spz=600295, no text found,
# For boat track_id=167: no additional info was found.
# For boat track_id=170: no additional info was found.
# For boat track_id=173: decoded_spz=303084-P, decoded_text=MAX. 8 osob,
# For boat track_id=176: decoded_spz=303084-P, no text found,
# For boat track_id=179: no additional info was found.
# For boat track_id=183: no spz found, no text found, other_info={'min': {184: 325502}, 'max': {184: 325523}, 'label': {184: 'boat_alt'}},
# For boat track_id=184: no spz found, no text found, other_info={'min': {184: 325502}, 'max': {184: 325523}, 'label': {184: 'boat_alt'}},
# For boat track_id=189: no spz found, decoded_text=???;Půjčovna, other_info={'min': {187: 325599}, 'max': {187: 325624}, 'label': {187: 'spz_alt'}},
# For boat track_id=190: no spz found, decoded_text=???,
# For boat track_id=192: no additional info was found.
# For boat track_id=194: decoded_spz=600711-P, no text found,
# For boat track_id=196: no additional info was found.
# For boat track_id=199: no spz found, decoded_text=???,
# For boat track_id=201: no spz found, no text found, other_info={'min': {202: 328889}, 'max': {202: 328898}, 'label': {202: 'boat_alt'}},
# For boat track_id=202: no spz found, no text found, other_info={'min': {202: 328889}, 'max': {202: 328898}, 'label': {202: 'boat_alt'}},
# For boat track_id=204: no additional info was found.
# For boat track_id=208: no additional info was found.
# For boat track_id=210: decoded_spz=50087?, no text found,
# For boat track_id=213: no additional info was found.
# For boat track_id=216: decoded_spz=304173-P, decoded_text=???,
# For boat track_id=219: no additional info was found.
# For boat track_id=221: no additional info was found.
# For boat track_id=223: no additional info was found.
# For boat track_id=226: decoded_spz=601095-P, no text found,
# For boat track_id=228: decoded_spz=601?55-P, no text found,
# For boat track_id=230: no additional info was found.
# For boat track_id=231: no spz found, no text found, other_info={'min': {231: 345013}, 'max': {231: 345059}, 'label': {231: 'boat_alt'}},
# For boat track_id=233: no additional info was found.
# For boat track_id=236: no additional info was found.
# For boat track_id=239: decoded_spz=Boženka, decoded_text=???,
# For boat track_id=243: no additional info was found.
# For boat track_id=247: no additional info was found.
# For boat track_id=249: decoded_spz=600293, no text found,
# For boat track_id=251: no additional info was found.
# For boat track_id=252: no additional info was found.
# For boat track_id=254: no additional info was found.
# For boat track_id=257: no additional info was found.
# For boat track_id=260: decoded_spz=Elektra, decoded_text=???,
# For boat track_id=263: decoded_spz=600042-P, decoded_text=MAX. 8 osob,
# For boat track_id=266: no spz found, decoded_text=!MAX. 8 osob,
# For boat track_id=268: no spz found, decoded_text=!MAX. 8 osob,
# For boat track_id=272: no additional info was found.
# For boat track_id=275: no additional info was found.
# For boat track_id=278: no spz found, decoded_text=???,
# For boat track_id=281: no additional info was found.
# For boat track_id=283: decoded_spz=KASANDRA, no text found,
# For boat track_id=287: decoded_spz=???409-P, no text found,
# For boat track_id=290: no additional info was found.
# For boat track_id=293: no additional info was found.
# For boat track_id=296: no additional info was found.
# For boat track_id=300: no additional info was found.
# For boat track_id=301: decoded_spz=303955-P, decoded_text=???,
# For boat track_id=304: decoded_spz=601477-P, no text found,
# For boat track_id=307: no additional info was found.
# For boat track_id=308: no additional info was found.
# For boat track_id=311: decoded_spz=334005-P, no text found,
# For boat track_id=313: no additional info was found.
# For boat track_id=315: no additional info was found.
# For boat track_id=316: no additional info was found.
# For boat track_id=317: no additional info was found.
# For boat track_id=318: no additional info was found.
# For boat track_id=319: no additional info was found.
# For boat track_id=320: decoded_spz=60075?, no text found,
# For boat track_id=321: no additional info was found.
# For boat track_id=323: decoded_spz=601723-P, no text found,
# For boat track_id=325: no additional info was found.
# For boat track_id=327: no additional info was found.
# For boat track_id=329: decoded_spz=600293, no text found,
# For boat track_id=331: no additional info was found.
# For boat track_id=332: no additional info was found.
# For boat track_id=333: no additional info was found.
# For boat track_id=335: no additional info was found.
# For boat track_id=336: no additional info was found.
# For boat track_id=337: no additional info was found.
# For boat track_id=339: no additional info was found.
# For boat track_id=341: no additional info was found.
# For boat track_id=342: no additional info was found.
# For boat track_id=343: decoded_spz=600792, no text found,
# For boat track_id=345: decoded_spz=600296, no text found,
# For boat track_id=347: decoded_spz=304095-P, no text found,
# For boat track_id=350: no additional info was found.
# For boat track_id=354: no additional info was found.
# For boat track_id=355: no additional info was found.
# For boat track_id=356: decoded_spz=301929-P, no text found,
# For boat track_id=358: no additional info was found.
# For boat track_id=359: decoded_spz=800571-P, no text found,
# For boat track_id=361: decoded_spz=601645, no text found,
# For boat track_id=363: no additional info was found.
# For boat track_id=364: decoded_spz=601493, no text found,
# For boat track_id=366: decoded_spz=600296, no text found, other_info={'min': {368: 785300}, 'max': {368: 785327}, 'label': {368: 'spz_alt'}},
# For boat track_id=369: decoded_spz=600295, no text found, other_info={'min': {371: 785727}, 'max': {371: 785765}, 'label': {371: 'spz_alt'}},
# For boat track_id=372: decoded_spz=600792, no text found,
# For boat track_id=374: decoded_spz=600?94, no text found,
# For boat track_id=376: decoded_spz=600297, no text found, other_info={'min': {378: 792394}, 'max': {378: 792436}, 'label': {378: 'spz_alt'}},
# For boat track_id=379: decoded_spz=600793, no text found,
# For boat track_id=381: no additional info was found.
# For boat track_id=382: decoded_spz=500873, no text found,
# For boat track_id=384: decoded_spz=600239-P, no text found, other_info={'min': {386: 796510}, 'max': {386: 796536}, 'label': {386: 'spz_alt'}},
# For boat track_id=387: decoded_spz=600294, no text found, other_info={'min': {389: 799416}, 'max': {389: 799457}, 'label': {389: 'spz_alt'}},
# For boat track_id=390: decoded_spz=601856, no text found,
# For boat track_id=392: decoded_spz=600293, no text found, other_info={'min': {393: 804783}, 'max': {393: 804795}, 'label': {393: 'spz_alt'}},
# For boat track_id=395: no spz found, no text found, other_info={'min': {396: 805192}, 'max': {396: 805208}, 'label': {396: 'spz_alt'}},
# For boat track_id=397: no spz found, no text found, other_info={'min': {398: 805302}, 'max': {398: 805316}, 'label': {398: 'spz_alt'}},
# For boat track_id=399: no additional info was found.
# For boat track_id=400: decoded_spz=304306-P, no text found, other_info={'min': {402: 806975}, 'max': {402: 807013}, 'label': {402: 'spz_alt'}},
# For boat track_id=404: no additional info was found.
# For boat track_id=405: no spz found, no text found, other_info={'min': {406: 809124}, 'max': {406: 809137}, 'label': {406: 'spz_alt'}},
# For boat track_id=407: no additional info was found.
# For boat track_id=408: decoded_spz=600293, no text found, other_info={'min': {409: 810899}, 'max': {409: 810924}, 'label': {409: 'spz_alt'}},
# For boat track_id=411: decoded_spz=303585-P, no text found, other_info={'min': {413: 811691}, 'max': {413: 811715}, 'label': {413: 'spz_alt'}},
# For boat track_id=414: decoded_spz=107302, no text found, other_info={'min': {416: 812681}, 'max': {416: 812695}, 'label': {416: 'spz_alt'}},
# For boat track_id=417: decoded_spz=601899, no text found,
# For boat track_id=419: decoded_spz=600293, no text found, other_info={'min': {420: 813933}, 'max': {420: 813943}, 'label': {420: 'spz_alt'}},
# For boat track_id=422: no additional info was found.
# For boat track_id=424: decoded_spz=600293, no text found, other_info={'min': {426: 819125}, 'max': {426: 819143}, 'label': {426: 'spz_alt'}},
# For boat track_id=427: no additional info was found.
# For boat track_id=428: no spz found, no text found, other_info={'min': {429: 820174}, 'max': {429: 820184}, 'label': {429: 'spz_alt'}},
# For boat track_id=430: decoded_spz=303585-P, no text found, other_info={'min': {432: 826150}, 'max': {432: 826212}, 'label': {432: 'spz_alt'}},
# For boat track_id=433: decoded_spz=600418, no text found, other_info={'min': {435: 829159}, 'max': {435: 829180}, 'label': {435: 'spz_alt'}},
# For boat track_id=436: no additional info was found.
# For boat track_id=438: decoded_spz=P-60075?, no text found, other_info={'min': {440: 830184}, 'max': {440: 830244}, 'label': {440: 'spz_alt'}},
# For boat track_id=441: decoded_spz=302593, no text found,
# For boat track_id=443: decoded_spz=P-300156, no text found,
# For boat track_id=445: decoded_spz=601302-P, no text found,
# For boat track_id=447: no additional info was found.
# For boat track_id=448: decoded_spz=601723-P, no text found,
# For boat track_id=450: no additional info was found.
# For boat track_id=451: no spz found, no text found, other_info={'min': {452: 842587}, 'max': {452: 842596}, 'label': {452: 'spz_alt'}},
# For boat track_id=453: decoded_spz=600239-P, no text found, other_info={'min': {455: 843205}, 'max': {455: 843228}, 'label': {455: 'spz_alt'}},
# For boat track_id=456: decoded_spz=600042-P, no text found,
# For boat track_id=458: decoded_spz=601302-P, no text found,
# For boat track_id=460: decoded_spz=60029f?, no text found, other_info={'min': {461: 846474}, 'max': {461: 846505}, 'label': {461: 'spz_alt'}},
# For boat track_id=463: decoded_spz=500954, no text found,
# For boat track_id=465: decoded_spz=601723-P, no text found,
# For boat track_id=467: no spz found, no text found, other_info={'min': {468: 850760}, 'max': {468: 850783}, 'label': {468: 'spz_alt'}},
# For boat track_id=469: decoded_spz=?00f792, no text found, other_info={'min': {470: 851512}, 'max': {470: 851533}, 'label': {470: 'spz_alt'}},
# For boat track_id=472: decoded_spz=, no text found,
# For boat track_id=474: no spz found, no text found, other_info={'min': {475: 853051}, 'max': {475: 853078}, 'label': {475: 'spz_alt'}},
# For boat track_id=476: decoded_spz=P-300456, no text found,
# For boat track_id=478: decoded_spz=601095-P, no text found, other_info={'min': {478: 854710, 479: 854727}, 'max': {478: 854768, 479: 854745}, 'label': {478: 'boat_alt', 479: 'spz_alt'}},
# For boat track_id=480: no additional info was found.
# For boat track_id=481: decoded_spz=600434, no text found,
# For boat track_id=483: decoded_spz=304162-P, no text found, other_info={'min': {485: 857643}, 'max': {485: 857685}, 'label': {485: 'spz_alt'}},
# For boat track_id=486: decoded_spz=304162-P, no text found, other_info={'min': {488: 857929}, 'max': {488: 857985}, 'label': {488: 'spz_alt'}},
# For boat track_id=489: decoded_spz=600687-P, no text found,
# For boat track_id=491: decoded_spz=600295, no text found, other_info={'min': {493: 859566}, 'max': {493: 859596}, 'label': {493: 'spz_alt'}},
# For boat track_id=495: decoded_spz=?03427, no text found,
# For boat track_id=497: decoded_spz=600792, no text found, other_info={'min': {499: 861657}, 'max': {499: 861691}, 'label': {499: 'spz_alt'}},
# For boat track_id=500: decoded_spz=600293, no text found, other_info={'min': {502: 862912}, 'max': {502: 862926}, 'label': {502: 'spz_alt'}},
# For boat track_id=503: decoded_spz=600?94, no text found, other_info={'min': {505: 865516}, 'max': {505: 865539}, 'label': {505: 'spz_alt'}},
# For boat track_id=506: no additional info was found.
# For boat track_id=507: no additional info was found.
# For boat track_id=508: no additional info was found.
# For boat track_id=509: no spz found, no text found, other_info={'min': {510: 868883}, 'max': {510: 868899}, 'label': {510: 'spz_alt'}},
# For boat track_id=511: decoded_spz=600293, no text found, other_info={'min': {513: 870174}, 'max': {513: 870196}, 'label': {513: 'spz_alt'}},
# For boat track_id=514: decoded_spz=600293, no text found, other_info={'min': {516: 872212}, 'max': {516: 872225}, 'label': {516: 'spz_alt'}},
# For boat track_id=517: decoded_spz=302376-P, no text found,
# For boat track_id=519: decoded_spz=601645, no text found, other_info={'min': {521: 874806}, 'max': {521: 874822}, 'label': {521: 'spz_alt'}},
# For boat track_id=522: no additional info was found.
# For boat track_id=523: decoded_spz=302376-P, no text found,
# For boat track_id=525: no spz found, no text found, other_info={'min': {526: 876581}, 'max': {526: 876612}, 'label': {526: 'spz_alt'}},
# For boat track_id=527: no additional info was found.
# For boat track_id=528: no spz found, no text found, other_info={'min': {529: 877478}, 'max': {529: 877511}, 'label': {529: 'spz_alt'}},
# For boat track_id=530: no spz found, no text found, other_info={'min': {531: 877575}, 'max': {531: 877605}, 'label': {531: 'spz_alt'}},
# For boat track_id=532: no spz found, no text found, other_info={'min': {533: 877693}, 'max': {533: 877729}, 'label': {533: 'spz_alt'}},
# For boat track_id=534: decoded_spz=60029?, no text found, other_info={'min': {535: 878759}, 'max': {535: 878786}, 'label': {535: 'spz_alt'}},
# For boat track_id=537: no additional info was found.
# For boat track_id=538: no spz found, no text found, other_info={'min': {539: 880106}, 'max': {539: 880124}, 'label': {539: 'spz_alt'}},
# For boat track_id=540: no additional info was found.
# For boat track_id=541: decoded_spz=600296, no text found, other_info={'min': {542: 882002}, 'max': {542: 882025}, 'label': {542: 'spz_alt'}},
# For boat track_id=544: no additional info was found.
# For boat track_id=545: decoded_spz=304205-P, no text found, other_info={'min': {547: 884064}, 'max': {547: 884092}, 'label': {547: 'spz_alt'}},
# For boat track_id=548: decoded_spz=600293, no text found, other_info={'min': {550: 885570}, 'max': {550: 885594}, 'label': {550: 'spz_alt'}},
# For boat track_id=551: no additional info was found.
# For boat track_id=552: decoded_spz=600293, no text found, other_info={'min': {553: 885595}, 'max': {553: 885621}, 'label': {553: 'spz_alt'}},
# For boat track_id=555: decoded_spz=303427, no text found,
# For boat track_id=557: decoded_spz=600293, no text found, other_info={'min': {559: 891677}, 'max': {559: 891695}, 'label': {559: 'spz_alt'}},
# For boat track_id=560: no additional info was found.
# For boat track_id=561: no additional info was found.
# For boat track_id=562: decoded_spz=600293, no text found,
# For boat track_id=564: decoded_spz=P-600752, no text found, other_info={'min': {566: 899516}, 'max': {566: 899540}, 'label': {566: 'spz_alt'}},
# For boat track_id=567: decoded_spz=601477-P, no text found,
# For boat track_id=569: decoded_spz=303331, no text found,
# For boat track_id=571: no spz found, no text found, other_info={'min': {571: 900227}, 'max': {571: 900373}, 'label': {571: 'boat_alt'}},
# For boat track_id=572: decoded_spz=304095-P, no text found, other_info={'min': {574: 900856}, 'max': {574: 900871}, 'label': {574: 'spz_alt'}},
# For boat track_id=575: decoded_spz=500873, no text found,
# For boat track_id=577: decoded_spz=600296, no text found, other_info={'min': {579: 904252}, 'max': {579: 904261}, 'label': {579: 'spz_alt'}},
# For boat track_id=580: decoded_spz=, no text found,
# For boat track_id=582: decoded_spz=300026-P, no text found, other_info={'min': {584: 908446}, 'max': {584: 908473}, 'label': {584: 'spz_alt'}},
# For boat track_id=586: decoded_spz=60079?, no text found, other_info={'min': {587: 909861}, 'max': {587: 909896}, 'label': {587: 'spz_alt'}},
# For boat track_id=589: decoded_spz=302591, no text found,
# For boat track_id=591: decoded_spz=600294, no text found, other_info={'min': {593: 913655}, 'max': {593: 913674}, 'label': {593: 'spz_alt'}},
# For boat track_id=594: decoded_spz=601477-P, no text found,
# For boat track_id=596: decoded_spz=60025?, no text found, other_info={'min': {597: 915227}, 'max': {597: 915264}, 'label': {597: 'spz_alt'}},
# For boat track_id=599: decoded_spz=600494, no text found,
# For boat track_id=601: decoded_spz=P-600232, no text found,
# For boat track_id=603: decoded_spz=601899, no text found,
# For boat track_id=605: no additional info was found.
# For boat track_id=606: decoded_spz=BIANCA, no text found,
# For boat track_id=608: decoded_spz=?00792, no text found, other_info={'min': {610: 917432}, 'max': {610: 917483}, 'label': {610: 'spz_alt'}},
# For boat track_id=611: decoded_spz=P-600232, no text found, other_info={'min': {613: 916843}, 'max': {613: 916848}, 'label': {613: 'spz_alt'}},
# For boat track_id=614: decoded_spz=YEKEKE, no text found,
# For boat track_id=616: decoded_spz=600042-P, no text found,
# For boat track_id=618: decoded_spz=302254, no text found,
# For boat track_id=620: decoded_spz=6002??, no text found, other_info={'min': {622: 933650}, 'max': {622: 933658}, 'label': {622: 'spz_alt'}},
# For boat track_id=623: decoded_spz=303331, no text found,
# For boat track_id=625: decoded_spz=600296, no text found, other_info={'min': {627: 933659}, 'max': {627: 933694}, 'label': {627: 'spz_alt'}},
#     camera_id  boat_track_id  frame_id_min  frame_id_max label  \
# 0          01              0          1087          1108  boat
# 1          01              1         25048         25143  boat
# 2          01              4         58362         58428  boat
# 3          01              8         60451         60527  boat
# 4          01             13         61683         61760  boat
# ..        ...            ...           ...           ...   ...
# 379        02            616        926478        926503  boat
# 380        02            618        928791        928829  boat
# 381        02            620        933649        933658  boat
# 382        02            623        935625        935677  boat
# 383        02            625        933659        933704  boat
#
#              decoded_spz                                       decoded_text
# 0                    NaN                                                NaN
# 1    www.hausbotvilma.cz                                                NaN
# 2               303451-P                   www.housbotvilma.cz;Max. 10 Osob
# 3               303768-P           BLATOUCH;PŮJČOVNA-3;pronajemhousebotu.cz
# 4                    NaN  LINKA STRÁŽNICE - PETROC A ZPĚT Tel.: 603 371 350
# ..                   ...                                                ...
# 379             600042-P                                                NaN
# 380               302254                                                NaN
# 381               6002??                                                NaN
# 382               303331                                                NaN
# 383               600296                                                NaN
#
# [384 rows x 7 columns]

# %%
boats_traversal_df.to_csv('decoded_boat_traversals.csv')
